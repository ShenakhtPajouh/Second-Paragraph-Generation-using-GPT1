# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd '/content/drive/My Drive/shared-works/Thread-1'
# Out:
# /content/drive/My Drive/shared-works/Thread-1

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # **The base model**

# %%
with open('train_loss_results.pkl','rb') as pkl:
    trains=pickle.load(pkl)
    
trains=trains[:-50]

with open('./Data/language_model/pickle/train_loss_results.pkl', 'rb') as pkl:
    trains1= pickle.load(pkl)

# %%
plt.figure(figsize=(13, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(trains+trains1[:89]+trains1[137:]);

# %%
trains_p = np.exp(trains).tolist()
trains1_p=np.exp(trains1).tolist()

# %%
plt.figure(figsize=(13, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(trains_p+trains1_p[:89]+trains1_p[137:]);

# %%
with open('validation_loss_results.pkl', 'rb') as pkl:
    validation = pickle.load(pkl)

validation=validation[:-50]

with open('./Data/language_model/pickle/validation_loss_results.pkl', 'rb') as pkl:
    validation1 = pickle.load(pkl)

# %%
plt.figure(figsize=(15, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(validation+validation1[:89]+validation1[137:-50]);

# %%
validation_p = np.exp(validation).tolist()
validation1_p=np.exp(validation1).tolist()

# %%
plt.figure(figsize=(15, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(validation_p+validation1_p[:89]+validation1_p[137:-50]);

# %% [markdown]
# # **The model without segment embeddings**

# %%
with open('./Data/interpretation/no_segment/pickle/train_loss_results.pkl', 'rb') as pkl:
    trains1= pickle.load(pkl)

# %%
plt.figure(figsize=(13, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(trains1);

# %%
trains1_p=np.exp(trains1).tolist()

# %%
plt.figure(figsize=(13, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(trains1_p);

# %%
with open('./Data/interpretation/no_segment/pickle/validation_loss_results.pkl', 'rb') as pkl:
    validation1 = pickle.load(pkl)

# %%
plt.figure(figsize=(15, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(validation1);

# %%
validation1_p=np.exp(validation1).tolist()

# %%
plt.figure(figsize=(15, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(validation1_p);

# %% [markdown]
# # **The model with equal segment embeddings**

# %%
with open('./Data/interpretation/equal_segment/pickle/train_loss_results.pkl', 'rb') as pkl:
    trains1= pickle.load(pkl)

# %%
plt.figure(figsize=(13, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(trains1);

# %%
trains1_p=np.exp(trains1).tolist()

# %%
plt.figure(figsize=(13, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(trains1_p);

# %%
with open('./Data/interpretation/equal_segment/pickle/validation_loss_results.pkl', 'rb') as pkl:
    validation1 = pickle.load(pkl)

# %%
plt.figure(figsize=(15, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(validation1);

# %%
validation1_p=np.exp(validation1).tolist()

# %%
plt.figure(figsize=(15, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("Perplexity", fontsize=13)
ax.plot(validation1_p);

# %%
def STLR(t, cut_frac = 0.1, ratio = 32, lr_max = 0.002, T = 1400000):
    cut = int(T * cut_frac)
    p = t / cut if t < cut else 1 - (t - cut) / (cut * (ratio - 1))
    lr = lr_max * (1 + p * (ratio - 1)) / ratio
    return lr

# %%
f = [STLR(i) for i in range(1400000)]
plt.figure(figsize=(13, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)  
ax.set_ylabel("STLR", fontsize=13)
ax.plot(f);
